# %%
from sklearn.preprocessing import OrdinalEncoder
import pandas as pd

education_levels = [['High School'], ['Bachelor'], ['Master'], ['PhD']]

encoder = OrdinalEncoder(categories=[['High School', 'Bachelor', 'Master', 'PhD']])

encoded = encoder.fit_transform(education_levels)

df = pd.DataFrame({
    'Original': [x[0] for x in education_levels],
    'Encoded': encoded.flatten()
})

print(df)
# Out:
#       Original  Encoded
# 0  High School      0.0
# 1     Bachelor      1.0
# 2       Master      2.0
# 3          PhD      3.0
